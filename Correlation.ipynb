# %%
import pandas

# %%
def correlation(data, method, caption):
    """Calculates the correlation coefficients between columns.
    Displays them in descending order of their absolute values."""
    columns = list(data)
    coefficients = data.astype(float).corr(method=method)
    results = []
    for i in range(len(columns)):
        for j in range(i + 1, len(columns)):
            coefficient = coefficients[columns[i]][columns[j]]
            results.append((
                abs(coefficient), coefficient,
                columns[i] + ' x ' + columns[j]))
    print('# ' + caption + ', ' + method)
    for result in reversed(sorted(results)):
        abs_coefficient, coefficient, columns_pair = result
        print (coefficient, columns_pair)

# %%
# Training dataset
training_data = pandas.read_csv('in/cs-training.csv')
training_data.drop(training_data.columns[0], axis=1, inplace=True)
for method in ('pearson', 'spearman'):
    correlation(training_data, method, 'training')
# Out:
# # training, pearson
# (0.99279618259160096, 'NumberOfTimes90DaysLate x NumberOfTime60-89DaysPastDueNotWorse')
# (0.98700544747994545, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfTime60-89DaysPastDueNotWorse')
# (0.98360268128207107, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfTimes90DaysLate')
# (0.43395860305532008, 'NumberOfOpenCreditLinesAndLoans x NumberRealEstateLoansOrLines')
# (-0.21330257804499639, 'age x NumberOfDependents')
# (0.14770531827119118, 'age x NumberOfOpenCreditLinesAndLoans')
# (0.12558696457286117, 'SeriousDlqin2yrs x NumberOfTime30-59DaysPastDueNotWorse')
# (0.1249589610947737, 'MonthlyIncome x NumberRealEstateLoansOrLines')
# (0.12468428521270425, 'NumberRealEstateLoansOrLines x NumberOfDependents')
# (0.12004602812504976, 'DebtRatio x NumberRealEstateLoansOrLines')
# (0.11717461344362123, 'SeriousDlqin2yrs x NumberOfTimes90DaysLate')
# (-0.11538551846889157, 'SeriousDlqin2yrs x age')
# (0.10226086105037467, 'SeriousDlqin2yrs x NumberOfTime60-89DaysPastDueNotWorse')
# (0.091454657698281275, 'MonthlyIncome x NumberOfOpenCreditLinesAndLoans')
# (-0.07998434978061833, 'NumberOfOpenCreditLinesAndLoans x NumberOfTimes90DaysLate')
# (-0.071076734958510926, 'NumberOfOpenCreditLinesAndLoans x NumberOfTime60-89DaysPastDueNotWorse')
# (0.065322070345503039, 'NumberOfOpenCreditLinesAndLoans x NumberOfDependents')
# (-0.062995157801085264, 'age x NumberOfTime30-59DaysPastDueNotWorse')
# (0.062647270222236151, 'MonthlyIncome x NumberOfDependents')
# (-0.06100470827606274, 'age x NumberOfTimes90DaysLate')
# (-0.057159464299109293, 'age x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.055312236174244779, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfOpenCreditLinesAndLoans')
# (0.04956528631507208, 'DebtRatio x NumberOfOpenCreditLinesAndLoans')
# (0.046047943522171259, 'SeriousDlqin2yrs x NumberOfDependents')
# (-0.045205216455485281, 'NumberOfTimes90DaysLate x NumberRealEstateLoansOrLines')
# (-0.040672697741841783, 'DebtRatio x NumberOfDependents')
# (-0.039722332366855843, 'NumberRealEstateLoansOrLines x NumberOfTime60-89DaysPastDueNotWorse')
# (0.037717386789533965, 'age x MonthlyIncome')
# (0.033150272947223926, 'age x NumberRealEstateLoansOrLines')
# (-0.030564534653276063, 'NumberOfTime30-59DaysPastDueNotWorse x NumberRealEstateLoansOrLines')
# (-0.029668568469318399, 'SeriousDlqin2yrs x NumberOfOpenCreditLinesAndLoans')
# (-0.02871226752754567, 'DebtRatio x MonthlyIncome')
# (0.024187804139156874, 'age x DebtRatio')
# (-0.019745546771059896, 'SeriousDlqin2yrs x MonthlyIncome')
# (-0.012742849255039143, 'MonthlyIncome x NumberOfTimes90DaysLate')
# (-0.011280732694152527, 'RevolvingUtilizationOfUnsecuredLines x NumberOfOpenCreditLinesAndLoans')
# (-0.011115549123717421, 'MonthlyIncome x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.010921997669854445, 'NumberOfTime60-89DaysPastDueNotWorse x NumberOfDependents')
# (-0.010217360630424764, 'NumberOfTime30-59DaysPastDueNotWorse x MonthlyIncome')
# (-0.010175866940909493, 'NumberOfTimes90DaysLate x NumberOfDependents')
# (-0.0083196401068189787, 'DebtRatio x NumberOfTimes90DaysLate')
# (-0.0076021198264561995, 'SeriousDlqin2yrs x DebtRatio')
# (-0.0075330993093348083, 'DebtRatio x NumberOfTime60-89DaysPastDueNotWorse')
# (0.0071238906465638544, 'RevolvingUtilizationOfUnsecuredLines x MonthlyIncome')
# (-0.0070381163359834343, 'SeriousDlqin2yrs x NumberRealEstateLoansOrLines')
# (-0.0065419227904730129, 'NumberOfTime30-59DaysPastDueNotWorse x DebtRatio')
# (0.0062347134238417189, 'RevolvingUtilizationOfUnsecuredLines x NumberRealEstateLoansOrLines')
# (-0.005898182986468381, 'RevolvingUtilizationOfUnsecuredLines x age')
# (0.0039612049761634655, 'RevolvingUtilizationOfUnsecuredLines x DebtRatio')
# (-0.0026804493936820849, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfDependents')
# (-0.0018015025039439733, 'SeriousDlqin2yrs x RevolvingUtilizationOfUnsecuredLines')
# (0.0015573444607284638, 'RevolvingUtilizationOfUnsecuredLines x NumberOfDependents')
# (-0.0013135009632522091, 'RevolvingUtilizationOfUnsecuredLines x NumberOfTime30-59DaysPastDueNotWorse')
# (-0.001061246378135609, 'RevolvingUtilizationOfUnsecuredLines x NumberOfTimes90DaysLate')
# (-0.0010478272157644856, 'RevolvingUtilizationOfUnsecuredLines x NumberOfTime60-89DaysPastDueNotWorse')
# # training, spearman
# (0.47281745250519686, 'NumberOfOpenCreditLinesAndLoans x NumberRealEstateLoansOrLines')
# (0.40023854382598117, 'DebtRatio x NumberRealEstateLoansOrLines')
# (0.39113154100013559, 'MonthlyIncome x NumberRealEstateLoansOrLines')
# (0.34234942220955933, 'SeriousDlqin2yrs x NumberOfTimes90DaysLate')
# (0.320972444110526, 'NumberOfTimes90DaysLate x NumberOfTime60-89DaysPastDueNotWorse')
# (0.31196868986866461, 'MonthlyIncome x NumberOfOpenCreditLinesAndLoans')
# (0.27980669837334315, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.27834048719484261, 'RevolvingUtilizationOfUnsecuredLines x age')
# (0.27711062962961119, 'SeriousDlqin2yrs x NumberOfTime60-89DaysPastDueNotWorse')
# (0.25741100328547128, 'SeriousDlqin2yrs x NumberOfTime30-59DaysPastDueNotWorse')
# (0.2527291051021055, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfTimes90DaysLate')
# (0.24037817700357897, 'SeriousDlqin2yrs x RevolvingUtilizationOfUnsecuredLines')
# (0.23766971492116987, 'RevolvingUtilizationOfUnsecuredLines x NumberOfTimes90DaysLate')
# (0.23437219790343297, 'RevolvingUtilizationOfUnsecuredLines x NumberOfTime30-59DaysPastDueNotWorse')
# (-0.22792669263102566, 'age x NumberOfDependents')
# (0.22676244846377913, 'DebtRatio x NumberOfOpenCreditLinesAndLoans')
# (0.2044605488001861, 'MonthlyIncome x NumberOfDependents')
# (0.18758501491113033, 'RevolvingUtilizationOfUnsecuredLines x NumberOfTime60-89DaysPastDueNotWorse')
# (0.16612182117486726, 'NumberRealEstateLoansOrLines x NumberOfDependents')
# (0.15806091448333068, 'age x NumberOfOpenCreditLinesAndLoans')
# (0.13461442686570746, 'age x MonthlyIncome')
# (-0.13457463012124093, 'NumberOfOpenCreditLinesAndLoans x NumberOfTimes90DaysLate')
# (-0.13093165485599076, 'DebtRatio x MonthlyIncome')
# (0.11769696937138878, 'RevolvingUtilizationOfUnsecuredLines x NumberOfDependents')
# (-0.11703396072688932, 'SeriousDlqin2yrs x age')
# (-0.10404881761365579, 'age x NumberOfTimes90DaysLate')
# (-0.1014717061432205, 'NumberOfTimes90DaysLate x NumberRealEstateLoansOrLines')
# (0.099840639523488983, 'NumberOfOpenCreditLinesAndLoans x NumberOfDependents')
# (-0.094647460688815938, 'age x NumberOfTime30-59DaysPastDueNotWorse')
# (-0.088378873800032343, 'MonthlyIncome x NumberOfTimes90DaysLate')
# (-0.08660380717648325, 'RevolvingUtilizationOfUnsecuredLines x NumberOfOpenCreditLinesAndLoans')
# (-0.085401170825273251, 'age x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.078205913405213656, 'RevolvingUtilizationOfUnsecuredLines x MonthlyIncome')
# (0.076563569186346908, 'RevolvingUtilizationOfUnsecuredLines x DebtRatio')
# (0.070994012197823642, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfDependents')
# (-0.066979752978501936, 'SeriousDlqin2yrs x MonthlyIncome')
# (0.063987395796312158, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfOpenCreditLinesAndLoans')
# (0.054218123307063971, 'age x NumberRealEstateLoansOrLines')
# (-0.053165210489436301, 'MonthlyIncome x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.048023490406473711, 'NumberOfOpenCreditLinesAndLoans x NumberOfTime60-89DaysPastDueNotWorse')
# (0.045972245366099874, 'SeriousDlqin2yrs x NumberOfDependents')
# (-0.044390674575278344, 'NumberRealEstateLoansOrLines x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.038586881474615628, 'SeriousDlqin2yrs x NumberOfOpenCreditLinesAndLoans')
# (0.038121950453532838, 'NumberOfTime30-59DaysPastDueNotWorse x DebtRatio')
# (-0.037621143078665702, 'DebtRatio x NumberOfDependents')
# (0.035285064902213163, 'NumberOfTime60-89DaysPastDueNotWorse x NumberOfDependents')
# (-0.034118365914276701, 'SeriousDlqin2yrs x NumberRealEstateLoansOrLines')
# (-0.031966544589622815, 'DebtRatio x NumberOfTimes90DaysLate')
# (0.030206072234766682, 'NumberOfTimes90DaysLate x NumberOfDependents')
# (0.02938249669370744, 'age x DebtRatio')
# (-0.027305820958461437, 'RevolvingUtilizationOfUnsecuredLines x NumberRealEstateLoansOrLines')
# (0.022256480353601549, 'NumberOfTime30-59DaysPastDueNotWorse x NumberRealEstateLoansOrLines')
# (0.020596833224552965, 'SeriousDlqin2yrs x DebtRatio')
# (-0.014611672276923934, 'NumberOfTime30-59DaysPastDueNotWorse x MonthlyIncome')
# (0.0012569656776248983, 'DebtRatio x NumberOfTime60-89DaysPastDueNotWorse')

# %%
# Test dataset
test_data = pandas.read_csv('in/cs-test.csv')
test_data.drop(test_data.columns[0], axis=1, inplace=True)
for method in ('pearson', 'spearman'):
    correlation(test_data, method, 'test')
# Out:
# # test, pearson
# (0.99411105422498003, 'NumberOfTimes90DaysLate x NumberOfTime60-89DaysPastDueNotWorse')
# (0.98879970539148254, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfTime60-89DaysPastDueNotWorse')
# (0.98568486730861449, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfTimes90DaysLate')
# (0.43114131547739243, 'NumberOfOpenCreditLinesAndLoans x NumberRealEstateLoansOrLines')
# (-0.2171539756251786, 'age x NumberOfDependents')
# (0.14378766275773319, 'age x NumberOfOpenCreditLinesAndLoans')
# (0.12923357869659158, 'DebtRatio x NumberRealEstateLoansOrLines')
# (0.12112577406439484, 'NumberRealEstateLoansOrLines x NumberOfDependents')
# (-0.084974355629491988, 'NumberOfOpenCreditLinesAndLoans x NumberOfTimes90DaysLate')
# (-0.076187909462431244, 'NumberOfOpenCreditLinesAndLoans x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.069226597739272283, 'age x NumberOfTime30-59DaysPastDueNotWorse')
# (-0.067605503480325929, 'age x NumberOfTimes90DaysLate')
# (0.065111561734806436, 'DebtRatio x NumberOfOpenCreditLinesAndLoans')
# (0.064706515919980279, 'NumberOfOpenCreditLinesAndLoans x NumberOfDependents')
# (-0.063166910662372663, 'age x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.060938004270476284, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfOpenCreditLinesAndLoans')
# (-0.049169680964987937, 'NumberOfTimes90DaysLate x NumberRealEstateLoansOrLines')
# (0.049163398614589869, 'MonthlyIncome x NumberRealEstateLoansOrLines')
# (-0.047219849560865459, 'DebtRatio x NumberOfDependents')
# (-0.043292197267347982, 'NumberRealEstateLoansOrLines x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.035426655426129675, 'NumberOfTime30-59DaysPastDueNotWorse x NumberRealEstateLoansOrLines')
# (0.035109477901528893, 'MonthlyIncome x NumberOfOpenCreditLinesAndLoans')
# (0.034493764535391186, 'age x DebtRatio')
# (0.026705504060547738, 'age x NumberRealEstateLoansOrLines')
# (0.022483116211315182, 'age x MonthlyIncome')
# (0.02089434648017181, 'MonthlyIncome x NumberOfDependents')
# (-0.011119693792832159, 'DebtRatio x NumberOfTimes90DaysLate')
# (-0.011109573121092911, 'RevolvingUtilizationOfUnsecuredLines x NumberOfOpenCreditLinesAndLoans')
# (-0.010473155312941426, 'NumberOfTime60-89DaysPastDueNotWorse x NumberOfDependents')
# (-0.0099717503779855714, 'DebtRatio x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.009492099007556801, 'NumberOfTimes90DaysLate x NumberOfDependents')
# (-0.0085607305871411941, 'NumberOfTime30-59DaysPastDueNotWorse x DebtRatio')
# (-0.0072307887145497563, 'RevolvingUtilizationOfUnsecuredLines x age')
# (-0.0058466571439012224, 'DebtRatio x MonthlyIncome')
# (-0.0057459810510014329, 'MonthlyIncome x NumberOfTimes90DaysLate')
# (-0.0051454916709499652, 'MonthlyIncome x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.0051424641449837475, 'NumberOfTime30-59DaysPastDueNotWorse x MonthlyIncome')
# (0.0039761860577034935, 'RevolvingUtilizationOfUnsecuredLines x NumberRealEstateLoansOrLines')
# (0.0038408187937874587, 'RevolvingUtilizationOfUnsecuredLines x DebtRatio')
# (-0.0019792158257030648, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfDependents')
# (0.0019452121849923845, 'RevolvingUtilizationOfUnsecuredLines x NumberOfDependents')
# (-0.0013174229702993126, 'RevolvingUtilizationOfUnsecuredLines x NumberOfTimes90DaysLate')
# (-0.0009165780746575007, 'RevolvingUtilizationOfUnsecuredLines x NumberOfTime60-89DaysPastDueNotWorse')
# (0.00073757320805320123, 'RevolvingUtilizationOfUnsecuredLines x MonthlyIncome')
# (-0.00058109417058678232, 'RevolvingUtilizationOfUnsecuredLines x NumberOfTime30-59DaysPastDueNotWorse')
# (nan, 'SeriousDlqin2yrs x NumberOfDependents')
# (nan, 'SeriousDlqin2yrs x NumberOfTime60-89DaysPastDueNotWorse')
# (nan, 'SeriousDlqin2yrs x NumberRealEstateLoansOrLines')
# (nan, 'SeriousDlqin2yrs x NumberOfTimes90DaysLate')
# (nan, 'SeriousDlqin2yrs x NumberOfOpenCreditLinesAndLoans')
# (nan, 'SeriousDlqin2yrs x MonthlyIncome')
# (nan, 'SeriousDlqin2yrs x DebtRatio')
# (nan, 'SeriousDlqin2yrs x NumberOfTime30-59DaysPastDueNotWorse')
# (nan, 'SeriousDlqin2yrs x age')
# (nan, 'SeriousDlqin2yrs x RevolvingUtilizationOfUnsecuredLines')
# # test, spearman
# (0.47177156079727561, 'NumberOfOpenCreditLinesAndLoans x NumberRealEstateLoansOrLines')
# (0.39866557379301087, 'DebtRatio x NumberRealEstateLoansOrLines')
# (0.39361642179656131, 'MonthlyIncome x NumberRealEstateLoansOrLines')
# (0.31460445453430658, 'NumberOfTimes90DaysLate x NumberOfTime60-89DaysPastDueNotWorse')
# (0.31319463975337219, 'MonthlyIncome x NumberOfOpenCreditLinesAndLoans')
# (0.2827375000869034, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.28004119549016443, 'RevolvingUtilizationOfUnsecuredLines x age')
# (0.24060951108993156, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfTimes90DaysLate')
# (0.2379885237223455, 'RevolvingUtilizationOfUnsecuredLines x NumberOfTime30-59DaysPastDueNotWorse')
# (0.2353837633291514, 'RevolvingUtilizationOfUnsecuredLines x NumberOfTimes90DaysLate')
# (-0.23345906667341815, 'age x NumberOfDependents')
# (0.2287648536014531, 'DebtRatio x NumberOfOpenCreditLinesAndLoans')
# (0.20438349381449109, 'MonthlyIncome x NumberOfDependents')
# (0.19199387873813395, 'RevolvingUtilizationOfUnsecuredLines x NumberOfTime60-89DaysPastDueNotWorse')
# (0.16088426404803199, 'NumberRealEstateLoansOrLines x NumberOfDependents')
# (0.15387917710153817, 'age x NumberOfOpenCreditLinesAndLoans')
# (-0.1396529234472097, 'NumberOfOpenCreditLinesAndLoans x NumberOfTimes90DaysLate')
# (0.13556457751582368, 'age x MonthlyIncome')
# (-0.12865612030005216, 'DebtRatio x MonthlyIncome')
# (0.1177738474066886, 'RevolvingUtilizationOfUnsecuredLines x NumberOfDependents')
# (-0.11242407840477248, 'age x NumberOfTimes90DaysLate')
# (-0.10826261875126665, 'NumberOfTimes90DaysLate x NumberRealEstateLoansOrLines')
# (0.097213931696559425, 'NumberOfOpenCreditLinesAndLoans x NumberOfDependents')
# (-0.096182168832858864, 'age x NumberOfTime30-59DaysPastDueNotWorse')
# (-0.088766705991020919, 'MonthlyIncome x NumberOfTimes90DaysLate')
# (-0.085148188131328253, 'RevolvingUtilizationOfUnsecuredLines x MonthlyIncome')
# (-0.083170408112482219, 'RevolvingUtilizationOfUnsecuredLines x NumberOfOpenCreditLinesAndLoans')
# (-0.081222380946835371, 'age x NumberOfTime60-89DaysPastDueNotWorse')
# (0.078273720423303189, 'RevolvingUtilizationOfUnsecuredLines x DebtRatio')
# (0.072317148187567432, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfDependents')
# (0.064788325609970498, 'NumberOfTime30-59DaysPastDueNotWorse x NumberOfOpenCreditLinesAndLoans')
# (-0.053777126986087893, 'MonthlyIncome x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.047245959058407797, 'NumberRealEstateLoansOrLines x NumberOfTime60-89DaysPastDueNotWorse')
# (0.045220022956179662, 'age x NumberRealEstateLoansOrLines')
# (-0.043009262703961292, 'NumberOfOpenCreditLinesAndLoans x NumberOfTime60-89DaysPastDueNotWorse')
# (-0.042513534400389685, 'DebtRatio x NumberOfDependents')
# (-0.041944118528774513, 'DebtRatio x NumberOfTimes90DaysLate')
# (0.037498154160588937, 'NumberOfTime30-59DaysPastDueNotWorse x DebtRatio')
# (0.032790355853052566, 'NumberOfTimes90DaysLate x NumberOfDependents')
# (0.03185716681407931, 'NumberOfTime60-89DaysPastDueNotWorse x NumberOfDependents')
# (-0.02753279275202378, 'RevolvingUtilizationOfUnsecuredLines x NumberRealEstateLoansOrLines')
# (0.024634268893091813, 'age x DebtRatio')
# (0.018890496556072556, 'NumberOfTime30-59DaysPastDueNotWorse x NumberRealEstateLoansOrLines')
# (-0.015179036172012144, 'NumberOfTime30-59DaysPastDueNotWorse x MonthlyIncome')
# (-0.0053100351816842781, 'DebtRatio x NumberOfTime60-89DaysPastDueNotWorse')
# (nan, 'SeriousDlqin2yrs x NumberOfDependents')
# (nan, 'SeriousDlqin2yrs x NumberOfTime60-89DaysPastDueNotWorse')
# (nan, 'SeriousDlqin2yrs x NumberRealEstateLoansOrLines')
# (nan, 'SeriousDlqin2yrs x NumberOfTimes90DaysLate')
# (nan, 'SeriousDlqin2yrs x NumberOfOpenCreditLinesAndLoans')
# (nan, 'SeriousDlqin2yrs x MonthlyIncome')
# (nan, 'SeriousDlqin2yrs x DebtRatio')
# (nan, 'SeriousDlqin2yrs x NumberOfTime30-59DaysPastDueNotWorse')
# (nan, 'SeriousDlqin2yrs x age')
# (nan, 'SeriousDlqin2yrs x RevolvingUtilizationOfUnsecuredLines')
